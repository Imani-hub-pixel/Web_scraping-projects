# %% [markdown]
# Reading files

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\faith\OneDrive\Desktop\Data analysis\Python\Web scrapping\company_revenue_US.csv')

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3  UnitedHealth Group                  Healthcare
# 3     4               Apple                  Technology
# 4     5          CVS Health                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                680,985           5.1%  2,100,000     Bentonville, Arkansas
# 1                637,959          11.0%  1,556,000       Seattle, Washington
# 2                400,278           7.7%    400,000     Minnetonka, Minnesota
# 3                391,035           2.0%    164,000     Cupertino, California
# 4                372,809           4.2%    259,500  Woonsocket, Rhode Island

# %%
df_new=pd.read_excel(r'C:\Users\faith\OneDrive\Desktop\Data analysis\Python\Pandas\Breast.xlsx')

# %%
#pd.set_option('display.max.rows',569)
#pd.set_option('display.max.columns',32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df.loc[6]
# Out:
# Rank                                                   7
# Name                                            Alphabet
# Industry                  Technology and cloud computing
# Revenue (USD millions)                           350,018
# Revenue growth                                     13.9%
# Employees                                        183,323
# Headquarters                   Mountain View, California
# Name: 6, dtype: object

# %%
df[df['Rank']<10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3    UnitedHealth Group                      Healthcare
# 3     4                 Apple                      Technology
# 4     5            CVS Health                      Healthcare
# 5     6    Berkshire Hathaway                    Conglomerate
# 6     7              Alphabet  Technology and cloud computing
# 7     8           Exxon Mobil                       Petroleum
# 8     9  McKesson Corporation                      Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                680,985           5.1%  2,100,000      Bentonville, Arkansas
# 1                637,959          11.0%  1,556,000        Seattle, Washington
# 2                400,278           7.7%    400,000      Minnetonka, Minnesota
# ...

# %%
specific_industries=['Technology','Healthcare']
df[df['Industry'].isin(specific_industries)]
# Out:
#     Rank                  Name    Industry Revenue (USD millions)  \
# 2      3    UnitedHealth Group  Healthcare                400,278
# 3      4                 Apple  Technology                391,035
# 4      5            CVS Health  Healthcare                372,809
# 8      9  McKesson Corporation  Healthcare                308,951
# 14    15       Cardinal Health  Healthcare                226,827
# 19    20       Elevance Health  Healthcare                177,011
# 21    22        Meta Platforms  Technology                164,501
# 22    23               Centene  Healthcare                163,071
# 30    31                Nvidia  Technology                130,497
# 43    44     Dell Technologies  Technology                 95,567
# 60    61        HCA Healthcare  Healthcare                 70,603
# 83    84                    HP  Technology                 53,559
# 85    86                 Intel  Technology                 53,101
# ...

# %%
df[df['Industry'].str.contains('Technology')]
# Out:
#     Rank                  Name                        Industry  \
# 3      4                 Apple                      Technology
# 6      7              Alphabet  Technology and cloud computing
# 13    14             Microsoft  Technology and cloud computing
# 21    22        Meta Platforms                      Technology
# 30    31                Nvidia                      Technology
# 43    44     Dell Technologies                      Technology
# 67    68                   IBM  Technology and cloud computing
# 72    73             TD Synnex          Information Technology
# 83    84                    HP                      Technology
# 85    86                 Intel                      Technology
# 86    87                Oracle                      Technology
# 87    88              Broadcom                      Technology
# 94    95  Ingram Micro Holding                      Technology
#
#    Revenue (USD millions) Revenue growth Employees               Headquarters
# ...

# %%
df2=df.set_index('Industry')

# %%
df2.filter(items=['Name','Headquarters'],axis=1)
# Out:
#                                                                     Name  \
# Industry
# Retail                                                           Walmart
# Retail and cloud computing                                        Amazon
# Healthcare                                            UnitedHealth Group
# Technology                                                         Apple
# Healthcare                                                    CVS Health
# Conglomerate                                          Berkshire Hathaway
# Technology and cloud computing                                  Alphabet
# Petroleum                                                    Exxon Mobil
# Healthcare                                          McKesson Corporation
# Pharmacy wholesale                                               Cencora
# Financials                                                JPMorgan Chase
# Retail                                                  Costco Wholesale
# ...

# %%
df2.loc['Technology']
# Out:
#             Rank                  Name Revenue (USD millions) Revenue growth  \
# Industry
# Technology     4                 Apple                391,035           2.0%
# Technology    22        Meta Platforms                164,501          21.9%
# Technology    31                Nvidia                130,497         114.2%
# Technology    44     Dell Technologies                 95,567           8.1%
# Technology    84                    HP                 53,559          -0.3%
# Technology    86                 Intel                 53,101          -2.1%
# Technology    87                Oracle                 52,961           6.0%
# Technology    88              Broadcom                 52,432          46.4%
# Technology    95  Ingram Micro Holding                 47,984          -0.1%
#
#            Employees             Headquarters
# Industry
# Technology   164,000    Cupertino, California
# Technology    74,067   Menlo Park, California
# ...

# %%
df2.iloc[3]
# Out:
# Rank                                          4
# Name                                      Apple
# Revenue (USD millions)                  391,035
# Revenue growth                             2.0%
# Employees                               164,000
# Headquarters              Cupertino, California
# Name: Technology, dtype: object

# %%
df[df['Rank']<10].sort_values(by=['Industry','Rank'],ascending=False)
# Out:
#    Rank                  Name                        Industry  \
# 6     7              Alphabet  Technology and cloud computing
# 3     4                 Apple                      Technology
# 1     2                Amazon      Retail and cloud computing
# 0     1               Walmart                          Retail
# 7     8           Exxon Mobil                       Petroleum
# 8     9  McKesson Corporation                      Healthcare
# 4     5            CVS Health                      Healthcare
# 2     3    UnitedHealth Group                      Healthcare
# 5     6    Berkshire Hathaway                    Conglomerate
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 6                350,018          13.9%    183,323  Mountain View, California
# 3                391,035           2.0%    164,000      Cupertino, California
# 1                637,959          11.0%  1,556,000        Seattle, Washington
# ...
